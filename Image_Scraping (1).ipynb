# %%
pip install bing-image-downloader

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
mkdir Dataset #making new directory for images

# %%
from bing_image_downloader import downloader
downloader.download("indian male celebrity face",limit=100,output_dir='Dataset',adult_filter_off=False)
# Out:
# [!!]Indexing page: 1
#
# [%] Indexed 6 Images on Page 1.
#
# ...
#
# [%] Downloading Image #1 from https://topcelebritysurgery.com/wp-content/uploads/2015/11/Nicki-Minaj-Plastic-Surgery-500x350.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #2 from https://images-na.ssl-images-amazon.com/images/M/MV5BMTM1Nzk2NTA3Nl5BMl5BanBnXkFtZTcwMzEzODI0NA@@._V1_UY1200_CR92,0,630,1200_AL_.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #3 from https://wikibiopic.com/wp-content/uploads/2019/09/krishna-bharadwaj-Krishnabharadawaj3-wikibiopic-img_5d88681cd4181.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #4 from https://www.thevoiceofwoman.com/wp-content/uploads/2020/07/The-Packing-Guide_001.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #5 from https://www.thevoiceofwoman.com/wp-content/uploads/2020/07/Argan-Oil_001-1.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #6 from http://www.mancrushes.com/sites/default/files/daniel-casey-actor-0.jpg
# [%] File Downloaded !
#
#
# ...

# %%
from bing_image_downloader import downloader
downloader.download("indian female celebrity face",limit=100,output_dir='Dataset',adult_filter_off=False)
# Out:
# [!!]Indexing page: 1
#
# [%] Indexed 4 Images on Page 1.
#
# ...
#
# [%] Downloading Image #1 from https://im.rediff.com/movies/2013/sep/19katrina1.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #2 from https://wikibiopic.com/wp-content/uploads/2019/09/nanditha-jennifer-nanditha-jennifer-f3dcccd6-3b1c-4969-a29d-80f890ccb04-resize-750-wikibiopic-img_5d8f3bb123cef.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #3 from https://wikibiopic.com/wp-content/uploads/2019/09/sandra-amy-tv-actress-sandra-amy-thoppi-movie-audio-launch_142286024920-wikibiopic-img_5d91f64444a04.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #4 from https://www.wikibiopic.com/wp-content/uploads/2019/12/Aishwarya-Rajesh-wiki-Image.jpg
# [%] File Downloaded !
#
#
#
# [!!]Indexing page: 2
#
# [%] Indexed 6 Images on Page 2.
#
# ...
#
# ...

# %%
from bing_image_downloader import downloader
downloader.download("indian male face photography",limit=100,output_dir='Dataset',adult_filter_off=False)
# Out:
# [!!]Indexing page: 1
#
# [%] Indexed 12 Images on Page 1.
#
# ...
#
# [%] Downloading Image #1 from https://i.pinimg.com/736x/ff/16/06/ff160633c39f283048030ea30933ba42--indian-models-mens-hair.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #2 from https://i1.wp.com/fashionablymale.net/wp-content/uploads/2013/01/jon135890-800w.jpg?resize=490%2C606
# [%] File Downloaded !
#
# [%] Downloading Image #3 from http://artofuncertainty.org/Bios_-_artists_files/droppedImage_17.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #4 from https://i0.wp.com/ae01.alicdn.com/kf/HTB1tXs0Mr2pK1RjSZFsq6yNlXXaW.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #5 from https://1.bp.blogspot.com/-IfMkOikFhdw/XRHX4agAroI/AAAAAAAAAVU/R7Y-KHIY4nU-q_IesOCVEW9tG9N5Cjz6gCK4BGAYYCw/s1600/278.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #6 from https://img.xcitefun.net/users/2014/07/361690,xcitefun-duck-face-baby-11.jpg
# [%] File Downloaded !
#
# ...

# %%
from bing_image_downloader import downloader
downloader.download("indian female face photography",limit=100,output_dir='Dataset',adult_filter_off=False)
# Out:
# [!!]Indexing page: 1
#
# [%] Indexed 12 Images on Page 1.
#
# ...
#
# [%] Downloading Image #1 from https://s-media-cache-ak0.pinimg.com/736x/07/18/ca/0718caeae9edf52dadcbab9417c8c00d--niqab-eyes-amazing-eyes.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #2 from https://i0.wp.com/ae01.alicdn.com/kf/H30bd4038cc5044cf856f4c9575d3f0b8x.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #3 from http://2.bp.blogspot.com/-3Enpx-xQis8/UEiqCXPumWI/AAAAAAAAPSQ/Q9P5uxjgWSY/s1600/Sunny_Leone_Wallpapers__02.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #4 from https://thumbs.dreamstime.com/z/indian-tribal-woman-portrait-18464052.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #5 from https://i.pinimg.com/736x/19/39/8b/19398b2eb7a48de7da7d61b11a729a3d.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #6 from https://121clicks.com/wp-content/uploads/2018/07/singular_beauties_fine_art_portrait_photography_02.jpg
# [%] File Downloaded !
#
# ...

# %%
from bing_image_downloader import downloader
downloader.download("asian people face",limit=100,output_dir='Dataset',adult_filter_off=False)
# Out:
# [!!]Indexing page: 1
#
# [%] Indexed 12 Images on Page 1.
#
# ...
#
# [%] Downloading Image #1 from http://papers.co/wallpaper/papers.co-hn65-asian-girl-face-dark-dress-23-wallpaper.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #2 from https://healthylifeboxx.com/wp-content/uploads/2019/05/Octopus-Attacks-Woman-As-She-Tried-To-Eat-It-Alive.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #3 from https://66.media.tumblr.com/ce7b85f7f16d9c3e4f576b11a9a50308/tumblr_nwfzygdXgA1u5bovuo1_640.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #4 from https://i.pinimg.com/736x/df/cf/76/dfcf76c9c45f616ab5962b8fd13a9beb.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #5 from https://i.pinimg.com/736x/e5/41/79/e54179695c297859c5cb6766f47e06c8--mysore-palace-south-india.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #6 from https://www.earwolf.com/wp-content/uploads/2012/12/reg_1024.CloudAtlas.mh_.102612.jpeg
# [%] File Downloaded !
#
# ...

# %%
from bing_image_downloader import downloader
downloader.download("female celebrity face",limit=100,output_dir='Dataset',adult_filter_off=False)
# Out:
# [!!]Indexing page: 1
#
# [%] Indexed 11 Images on Page 1.
#
# ...
#
# [%] Downloading Image #1 from http://pophaircuts.com/images/2013/08/Medium-Short-Hairstyles-2014-Katharine-McPhee-Hair.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #2 from http://media.allure.com/photos/57df3e0fd20277447bdad472/master/pass/video-ballerina-lauren-lovett.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #3 from https://www.10wallpaper.com/wallpaper/1200x900/1404/alice_goodwin_face_model-photo_HD_wallpaper_1200x900.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #4 from https://media.allure.com/photos/591e2a979a3e14303438645f/master/pass/GettyImages-629558124.jpg?mbid=social_retweet
# [%] File Downloaded !
#
# [%] Downloading Image #5 from https://i.pinimg.com/736x/ca/ea/ac/caeaac0003c57be328baf5cec8f646a8--goldie-hawn-famous-celebrities.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #6 from http://photos.costume-works.com/page/creative-diy-costume-ideas-for-women.jpg
# ...

# %%
from bing_image_downloader import downloader
downloader.download("female face photography",limit=100,output_dir='Dataset',adult_filter_off=False)
# Out:
# [!!]Indexing page: 1
#
# [%] Indexed 12 Images on Page 1.
#
# ...
#
# [%] Downloading Image #1 from https://thumbs.dreamstime.com/x/beautiful-model-face-fashion-eyeliner-make-up-22012167.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #2 from http://www.cs.cmu.edu/afs/cs.cmu.edu/academic/class/15463-f11/www/proj3/www/ytay/results/yiling_wide_mouth.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #3 from https://thumbs.dreamstime.com/z/young-attractive-woman-getting-ready-bathroom-10250892.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #4 from https://i.pinimg.com/736x/08/d5/0e/08d50edc538184b8b7e757e1d51fde11.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #5 from http://www.designboom.com/wp-content/uploads/2016/08/john-yuyi-social-media-tattoo-designboom-05.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #6 from https://flashbak.com/wp-content/uploads/2017/02/Mug-Shots-1960s-25-1280x799.jpg
# [%] File Downloaded !
#
# ...

# %%
from bing_image_downloader import downloader
downloader.download("male face photography",limit=100,output_dir='Dataset',adult_filter_off=False)
# Out:
# [!!]Indexing page: 1
#
# [%] Indexed 12 Images on Page 1.
#
# ...
#
# [%] Downloading Image #1 from https://i.pinimg.com/736x/c4/f4/a0/c4f4a0a0d228cf48d3fa63346d98a021--rainy-window-the-window.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #2 from http://www.wallpapersin4k.org/wp-content/uploads/2017/04/The-North-Face-Wallpaper-10.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #3 from https://www.sheclick.com/wp-content/uploads/2010/12/Full-Face-Tattoo-Design-for-Old-Women.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #4 from https://i1.wp.com/fashionablymale.net/wp-content/uploads/2012/06/aaron-o_connell3.jpg?resize=490%2C737
# [%] File Downloaded !
#
# [%] Downloading Image #5 from http://www.wallpapersin4k.org/wp-content/uploads/2017/04/Nature-Wallpaper-Iphone-21.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #6 from https://i0.wp.com/fashionablymale.net/wp-content/uploads/2016/07/igor-kolomiyets-by-michael-dar-5.jpg?resize=900%2C1350&amp;ssl=1
# ...

# %%
from bing_image_downloader import downloader
downloader.download("male celebrity face",limit=100,output_dir='Dataset',adult_filter_off=False)
# Out:
# [!!]Indexing page: 1
#
# [%] Indexed 12 Images on Page 1.
#
# ...
#
# [%] Downloading Image #1 from https://starschanges.com/wp-content/uploads/2016/08/alex-pettyfer-height-weight-age.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #2 from https://www.malemodelscene.net/wp-content/uploads/2019/08/James-Jagger-Rag-Bone-Photo-Project-2019-04.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #3 from https://photos.laineygossip.com/articles/harry-styles-pride-21sept17-13.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #4 from https://vz.cnwimg.com/wp-content/uploads/2015/02/Jimmy-Garoppolo.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #5 from https://keyassets-p2.timeincuk.net/wp/prod/wp-content/uploads/sites/30/2018/01/Josie-Gibson.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #6 from https://champions-speakers.co.uk/sites/default/files/styles/profile_gallery_sm/public/2020-02/charlie_martin_banner_0.jpg.jpeg?itok=dr00SPrA
# [%] File Downloaded !
#
# ...

# %%
from bing_image_downloader import downloader
downloader.download("male celebrity face",limit=100,output_dir='Dataset',adult_filter_off=False)
# Out:
# [!!]Indexing page: 1
#
# [%] Indexed 12 Images on Page 1.
#
# ...
#
# [%] Downloading Image #1 from https://starschanges.com/wp-content/uploads/2016/08/alex-pettyfer-height-weight-age.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #2 from https://www.malemodelscene.net/wp-content/uploads/2019/08/James-Jagger-Rag-Bone-Photo-Project-2019-04.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #3 from https://photos.laineygossip.com/articles/harry-styles-pride-21sept17-13.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #4 from https://vz.cnwimg.com/wp-content/uploads/2015/02/Jimmy-Garoppolo.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #5 from https://keyassets-p2.timeincuk.net/wp/prod/wp-content/uploads/sites/30/2018/01/Josie-Gibson.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #6 from https://champions-speakers.co.uk/sites/default/files/styles/profile_gallery_sm/public/2020-02/charlie_martin_banner_0.jpg.jpeg?itok=dr00SPrA
# [%] File Downloaded !
#
# ...

# %%
from bing_image_downloader import downloader
downloader.download("indian male model face",limit=100,output_dir='Dataset',adult_filter_off=False)
# Out:
# [!!]Indexing page: 1
#
# [%] Indexed 11 Images on Page 1.
#
# ...
#
# [%] Downloading Image #1 from http://2.bp.blogspot.com/-w4CHjYA1n4g/Tz22jU49F5I/AAAAAAAAAcQ/E7jxXMlkyGo/s1600/rodrigo-guirao-diaz+2+ARGENTINA.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #2 from https://www.theamazingmodels.com/models/models_images/latish_09e68.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #3 from http://1.bp.blogspot.com/-bXRNND_2jNY/URXwwJsdvuI/AAAAAAAAaWA/QvziVuS_kU4/s1600/Mohit+Nayak.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #4 from http://3.bp.blogspot.com/_Hwp9vvT57bo/TQNP1I_ZpbI/AAAAAAAABl8/w0tfHWh1n6w/s1600/Indian-Actress-Model-Beauty-Queen-Miss-Universe-Gul%2BPanag-Hot-Sexy-Legs-CrossedLegs-Thunder-Thigh-Mini-Pant-Photo-Stills-0888.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #5 from https://i0.wp.com/ae01.alicdn.com/kf/H195e2b9e1cd645d49c639cda60b0d406g.jpg
# [%] File Downloaded !
#
# ...

# %%
from bing_image_downloader import downloader
downloader.download("indian female model face",limit=100,output_dir='Dataset',adult_filter_off=False)
# Out:
# [!!]Indexing page: 1
#
# [%] Indexed 12 Images on Page 1.
#
# ...
#
# [%] Downloading Image #1 from https://thumbs.dreamstime.com/z/woman-costume-american-indian-young-34596545.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #2 from https://www.theamazingmodels.com/models/models_images/nimrat_67681.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #3 from https://flameinstitute.com/wp-content/uploads/2015/11/sapna-guleria-PO-canra-Bank-326x490.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #4 from https://img.buzzfeed.com/buzzfeed-static/static/2015-11/30/17/enhanced/webdr10/grid-cell-2441-1448921200-2.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #5 from https://thumbs.dreamstime.com/z/woman-silhouette-side-lacy-pants-lace-facing-sideways-35135728.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #6 from https://cdn.pixabay.com/photo/2017/04/29/19/03/beautiful-2271357_640.jpg
# [%] File Downloaded !
#
# ...

# %%
from bing_image_downloader import downloader
downloader.download("Black Men Beard Models face",limit=100,output_dir='Dataset',adult_filter_off=False)
# Out:
# [!!]Indexing page: 1
#
# [%] Indexed 12 Images on Page 1.
#
# ...
#
# [%] Downloading Image #1 from http://hairstylehub.com/wp-content/uploads/2017/03/patchy-beard.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #2 from https://www.beyondblackwhite.com/wp-content/uploads/2014/05/de5dbb0952098d89acf05a4726cae28c.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #3 from https://i.pinimg.com/originals/84/21/d3/8421d3ac7a9c3d111fe67212322ce03c.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #4 from https://i.mdel.net/newfaces/i/2011/10/Cristian-Codrin-by-Errikos-Andreou-8-723x1024.jpg
# [!] Issue getting: https://i.mdel.net/newfaces/i/2011/10/Cristian-Codrin-by-Errikos-Andreou-8-723x1024.jpg
# [!] Error:: <urlopen error [SSL: CERTIFICATE_VERIFY_FAILED] certificate verify failed: unable to get local issuer certificate (_ssl.c:1091)>
# [%] Downloading Image #4 from https://menhairdos.com/wp-content/uploads/2019/07/53371955_347220819247237_4236741806446846571_n.jpg
# ...

# %%
from bing_image_downloader import downloader
downloader.download("Beard Male Model Face",limit=100,output_dir='Dataset',adult_filter_off=False)
# Out:
# [!!]Indexing page: 1
#
# [%] Indexed 12 Images on Page 1.
#
# ...
#
# [%] Downloading Image #1 from http://3.bp.blogspot.com/-VdbChhZ8GsY/T9SZbxTRLGI/AAAAAAAAB1c/OFytP9b2U78/s1600/26+rafael+lazzini+polaroid.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #2 from https://hairstyleonpoint.com/wp-content/uploads/2014/11/a57670a0a08b15f658987173fbd3d38f.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #3 from https://i.pinimg.com/originals/20/04/89/20048969bd2c8f68701c3864f743e024.jpg
# [%] File Downloaded !
#
# [%] Downloading Image #4 from https://i2.wp.com/fashionablymale.net/wp-content/uploads/2016/01/domenicocianciotto_tysonvick_hufmag_05.jpg?resize=667%2C1000&amp;ssl=1
# [%] File Downloaded !
#
# [%] Downloading Image #5 from https://fashiondioxide.com/wp-content/uploads/2018/11/Beard-Styles-for-Oval-Face-Mens-Facial-Hair-Styles-for-Oval-Face-4.jpg
# [%] File Downloaded !
#
# ...
